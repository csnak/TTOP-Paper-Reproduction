# %%
import pandas as pd

# %%
df = pd.read_csv('TTO_dataset_410.csv')
df
# Out:
#          row_idx  YEAR        DATE       GAME_ID  INNING    PIT_ID    BAT_ID  \
# 0          58505  2006  2006-04-07  ANA200604070       1  escok001  damoj001
# 1          58506  2006  2006-04-07  ANA200604070       1  escok001  jeted001
# 2          58507  2006  2006-04-07  ANA200604070       1  escok001  shefg001
# 3          58508  2006  2006-04-07  ANA200604070       1  escok001  rodra001
# 4          58509  2006  2006-04-07  ANA200604070       1  chacs001  figgc001
# ...          ...   ...         ...           ...     ...       ...       ...
# 1653462  5648038  2019  2019-09-29  WAS201909290       6  clevm001  readr002
# 1653463  5648039  2019  2019-09-29  WAS201909290       6  clevm001  taylm002
# 1653464  5648041  2019  2019-09-29  WAS201909290       6  clevm001  adamm002
# 1653465  5648042  2019  2019-09-29  WAS201909290       6  clevm001  roblv001
# 1653466  5648044  2019  2019-09-29  WAS201909290       6  clevm001  dozib001
#
# ...

# %%
# df.columns
df.BATTER_IDX.value_counts()
# Out:
# BATTER_IDX
# 1     211894
# 2     204655
# 3     197810
# 4     191688
# 5     185712
# 6     178591
# 7     170296
# 8     159371
# 9     133590
# 10     16047
# 11      3154
# 12       477
# 13       120
# 14        44
# 15        12
# 16         5
# 17         1
# Name: count, dtype: int64

# %%
# df.PIT_ID.nunique()
# for col in df.select_dtypes('object').columns:
#     print(col, df[col].unique())

# print(df.YEAR, df.YEAR.unique())
# print(df.All_Tags.unique())
# print(df.Release_Date.unique())
# print(df.Steam_Deck_Status.unique())
# print(df.Release_Date)
print(df.YEAR.unique())
# Out:
# [2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019]

# %%
df_1 = pd.read_csv('TTO_dataset_510.csv')
df_1.head(10)
# Out:
#    YEAR        DATE       GAME_ID  INNING    PIT_ID    BAT_ID  WOBA_APP  \
# 0  2010  2010-04-04  BOS201004040       1  beckj002  jeted001      True
# 1  2010  2010-04-04  BOS201004040       1  beckj002  johnn001      True
# 2  2010  2010-04-04  BOS201004040       1  beckj002  teixm001      True
# 3  2010  2010-04-04  BOS201004040       1  sabac001  ellsj001      True
# 4  2010  2010-04-04  BOS201004040       1  sabac001  pedrd001      True
# 5  2010  2010-04-04  BOS201004040       1  sabac001  martv001      True
# 6  2010  2010-04-04  BOS201004040       2  beckj002  rodra001      True
# 7  2010  2010-04-04  BOS201004040       2  beckj002  canor001      True
# 8  2010  2010-04-04  BOS201004040       2  beckj002  posaj001      True
# 9  2010  2010-04-04  BOS201004040       2  beckj002  granc001      True
#
#    EVENT_WOBA_19  HAND_MATCH  BAT_HOME_IND  ...       BQ2  std_EVENT_WOBA_19  \
# 0           0.00         1.0             0  ...  0.382427          -0.316793
# ...

# %%
df_1.columns
# df_1.BQ.value_counts()
df_1.BQ2.value_counts()
# Out:
# BQ2
# 0.000000    2506
# 0.293490     196
# 0.291059     185
# 0.283863     185
# 0.286429     180
#             ...
# 0.306591       1
# 0.315981       1
# 0.362802       1
# 0.360004       1
# 0.313925       1
# Name: count, Length: 1148812, dtype: int64

# %%
# df_1[df_1['GAME_ID']] == 'BOS201004040'
# 'BOS201004040' in df_1['GAME_ID'].values
# df_1.GAME_ID == 'BOS201004040'
# df_1.GAME_ID.value_counts().get('BOS201004040', 0)
df_1.YEAR.min()
# Out:
# 2010

# %%
df_2 = pd.read_csv('retro_final_PA_1990-2020d.csv')
df_2
# Out:
# C:\Users\csnak\AppData\Local\Temp\ipykernel_17724\607304963.py:1: DtypeWarning: Columns (16,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2 = pd.read_csv('retro_final_PA_1990-2020d.csv')
#          row_idx       GAME_ID   PARK        DATE  YEAR HOME_TEAM_ID  \
# 0              1  ANA199704020  ANA01  1997-04-02  1997          ANA
# 1              2  ANA199704020  ANA01  1997-04-02  1997          ANA
# 2              3  ANA199704020  ANA01  1997-04-02  1997          ANA
# 3              4  ANA199704020  ANA01  1997-04-02  1997          ANA
# 4              5  ANA199704020  ANA01  1997-04-02  1997          ANA
# ...          ...           ...    ...         ...   ...          ...
# 5650376  5650377  WAS202009270  WAS11  2020-09-27  2020          WAS
# 5650377  5650378  WAS202009270  WAS11  2020-09-27  2020          WAS
# 5650378  5650379  WAS202009270  WAS11  2020-09-27  2020          WAS
# ...

# %%
df_2.columns
# Out:
# Index(['row_idx', 'GAME_ID', 'PARK', 'DATE', 'YEAR', 'HOME_TEAM_ID',
#        'AWAY_TEAM_ID', 'INNING', 'BAT_HOME_IND', 'BAT_ID', 'BAT_NAME',
#        'BAT_HAND', 'FIELD_POS', 'PIT_ID', 'PIT_NAME', 'PIT_HAND', 'COUNT',
#        'PITCH_SEQ_TX', 'EVENT_TX', 'HIT_VAL', 'HIT_BINARY',
#        'consecutive.bat.row', 'BATTER_SEQ_NUM', 'ORDER_CT', 'HAND_MATCH',
#        'SP_IND', 'HOME_DIV', 'AWAY_DIV', 'HOME_LEAGUE', 'AWAY_LEAGUE',
#        'IN_DIV', 'IN_LEAGUE', 'EVENT_OUTS_CT', 'OUTS_CT', 'EVENT_CODE',
#        'PA_IND', 'AB_IND', 'WOBA_APP', 'EVENT_RUNS', 'EVENT_PITCH_COUNT',
#        'PITCH_COUNT_CUMU', 'PITCH_COUNT_FINAL', 'DAYS_SINCE_SZN_START',
#        'PIT_REST', 'EVENT_WOBA', 'EVENT_WOBA_19', 'BASE_STATE'],
#       dtype='object')

# %%
# df_2.EVENT_TX.value_counts()
# print(df_2['EVENT_TX'], df_2['EVENT_TX'].unique())
df_2.BAT_HAND.value_counts()
# Out:
# BAT_HAND
# R    3030185
# L    1752598
# B     867598
# Name: count, dtype: int64

# %%
'BOS201004040' in df_2['GAME_ID'].values
# df_2.GAME_ID.value_counts().get('BOS201004040', 0)
# Out:
# True

# %%
df_2.YEAR.max()
# Out:
# 2020
